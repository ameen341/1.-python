# %%
# #1.Find the error in the following Python code:
import math
print(Math.sqrt(16))
# Out:
# 4.0

# %%
# Ans: print(Math.sqrt(16)) library math should be in small letter in print statement.
import math
print(math.sqrt(16))
# Out:
# 4.0

# %%
#2.Find the error in the following Python code:
def my_function():
    x += 5
    print(x)

x = 10
my_function()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[27], line 7
#       4     print(x)
#       6 x = 10
# ----> 7 my_function()
#
# Cell In[27], line 3, in my_function()
#       2 def my_function():
# ----> 3     x += 5
#       4     print(x)
#
# UnboundLocalError: cannot access local variable 'x' where it is not associated with a value

# %%
# Ans: x is modified inside the function without being declared as global.
def my_function():
    global X
    X += 5
    print(X)
X = 10 
my_function()
# Out:
# 15

# %%
#3.x = 5
if x = 10:
    print("x is 10")

# %%
# Ans: assignment operator has to correct ==
X = 5
if X==10:
    print("X is 10")

# %%
#4.
numbers = [5, 3, 8, 2]
print(numbers.sort())
# Out:
# [2, 3, 5, 8]

# %%
# Ans: need to add .sort() to sort the numbers.
numbers = [5, 3, 8, 2]
numbers.sort()
print(numbers)
# Out:
# [2, 3, 5, 8]

# %%
#5.
def square(n):
    return n * n

print(square(4))
# Out:
# 16

# %%
# Ans: fixed Code 
def square(n):
    square = n*n
    print(square)
square(4)
# Out:
# 16

# %%
#6.
my_tuple = (1, 2, 3)
my_tuple[1] = 5

# %%
# Ans: 
my_tuple = (1, 5, 3)

# %%
#7.
name = "Alice"
age = 25
print("My name is %s and I am %d years old" % (name))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 4
#       2 name = "Alice"
#       3 age = 25
# ----> 4 print("My name is %s and I am %d years old" % (name))
#
# TypeError: not enough arguments for format string

# %%
# Ans:
name = "Alice"
age = 25
print("Myname is",name, "I am",age, "years old")
# Out:
# Myname is Alice I am 25 years old

# %%
#8.
a = [1, 2, 3]
b = [1, 2, 3]
if a is b:
    print("Lists are equal")
# if a is b: this function has error.
if(a==b):
    print("Lists are equal")
# Out:
# Lists are equal

# %%
#9.
for i in range(5, 1):
    print(i)
#  for i in range(5, 1): this function has error 
for i in range(5, 1, -1):
    print(i)
# Out:
# 5
# 4
# 3
# 2

# %%
#10.
student = {"name": "John", "age": 20}
# print(student[name])
# print(student[name]) this line cause error 
print(student)
# Out:
# {'name': 'John', 'age': 20}
