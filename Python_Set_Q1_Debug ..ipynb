# %%
#1.Find the error in the following Python code:

for i in range(5) 
    print(i)
# missed colon in conditions
for i in range(5):
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#2.What will be the output of this code?

a = 10
b = "5"
# print(a + b)

# int+string its through an error, 

# output error
print(a + int(b))
# Out:
# 15

# %%
#3.What is the issue in this Python snippet?

# def add_numbers(a, b) 
     # return a + b
    
# missing colon : after (a, b)
def add_numbers(a, b):
    return a+b
add_numbers(6, 7)
# Out:
# 13

# %%
#4.Identify the bug in the following Python code:

# numbers = [1, 2, 3, 4]  
# print(numbers[4])

# Index error list index out of range.
numbers = [1, 2, 3, 4]
print(numbers[3])
# Out:
# 4

# %%
#5.Find the error in the following Python code:
# print "Hello, World!" 

# () missing parentheses
print("Hello, World!")
# Out:
# Hello, World!

# %%
#6.Find the error in the following Python code:
# x = 5 / 0

# Division error
X = 5/1 
print(int(X))
# Out:
# 5

# %%
#7.Find the error in the following Python code:
name = "Alice"
age = 25
# print("Name: " + name + ", Age: " + age)

# instead of + opearator comma has to put on print Statement.
print("Name: ", name, "Age: ", age)
# Out:
# Name:  Alice Age:  25

# %%
#8.Find the error
# for i in range(1, 10, -1):
#     print(i)
    
# error in range() function. range(start, stop, step) range start from 1 to 10 but here step value -1 is incorrect
for i in range(10, 1, -1):
    print(i)
# Out:
# 10
# 9
# 8
# 7
# 6
# 5
# 4
# 3
# 2

# %%
#9. Find the error in the following Python code:
# x = 10
# # if x = 5:
#     print("x is 5")
# error in operator should be comparison operator ==
x=10
if x==5:
    print("x is 5")
else:
    print(x)
# Out:
# 10

# %%
#10. Identify the error in the following function definition:

# def greet(name)
#     print("Hello, " + name)

# Colon missing after (name) 
def greet(name):
    print("Hello, " + name)
greet(name)
# Out:
# Hello, Alice
